# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

path = "avocado.csv"
df = pd.read_csv(path)
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
nbr = df[['AveragePrice','year']].groupby('year').mean().sort_values(by='AveragePrice', ascending=False)
nbr.reset_index(0, inplace=True)
nbr.head()
# Out:
#    year  AveragePrice
# 0  2017      1.515128
# 1  2015      1.375590
# 2  2018      1.347531
# 3  2016      1.338640

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=nbr['region'], y=nbr['AveragePrice'], palette="Reds_r")
plt.xlabel('Région', fontsize=15, color='#c0392b')
plt.ylabel("Prix Moyen\n", fontsize=15, color='#c0392b')
plt.title("Prix moyen des avocats selon la région", fontsize=18, color='#e74c3c')
plt.xticks(rotation= 45)
plt.tight_layout()

# %%
# create figure and axis
fig, ax = plt.subplots()
# plot histogram
ax.hist(df['AveragePrice'])
# set title and labels
ax.set_title("Prix moyen de l'avocat")
ax.set_xlabel('Prix moyen')
ax.set_ylabel('Frequence')
# Out:
# Text(0, 0.5, 'Frequence')

# %%
#plt.pie(df['AveragePrice'], labels=df['year'], autopct='%0.f%%', shadow=True, startangle=90)

fig1, ax1 = plt.subplots()
ax1.pie(df['AveragePrice'], explode=explode, labels=df['year'], autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-780700363caa> in <module>
#       1 #plt.pie(df['AveragePrice'], labels=df['year'], autopct='%0.f%%', shadow=True, startangle=90)
#       2
# ----> 3 fig1, ax1 = plt.subplots()
#       4 ax1.pie(df['AveragePrice'], explode=explode, labels=df['year'], autopct='%1.1f%%',
#       5         shadow=True, startangle=90)
#
# NameError: name 'plt' is not defined
